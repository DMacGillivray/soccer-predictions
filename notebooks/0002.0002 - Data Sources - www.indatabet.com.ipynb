# %% [markdown]
# # 0002.002 - Data Sources www.indatabet.com

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# This site has been taken down since the free data was downloaded
#
# This is a bit disappointing because it seemed to offer quite a range of odds data, including Pinnacle closing odds, and odds movements
#
# YouTube below demonstrating some soccer odds data

# %%
YouTubeVideo('eugx_iwN884', width=600, height=400)
